# %% [markdown]
# <Center>RAG using Langchain </center>

# %% [markdown]
# Import libraries

# %%
import os
os.environ['OPENAI_API_KEY'] = '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'

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI()
